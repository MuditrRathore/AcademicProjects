# %%
import numpy as np

# %%
a = np.array([
    [1.2, 3.5],
    [3.0, 4.5]
])

b = np.array([
    [6, 5],
    [3, 0.5]
])
vals = {}

# %%
for i in range(a.shape[0]) :
    for j in range(b.shape[0]) :
        q = a[i][0] + b[j][0]
        if(q in vals) :
            arr = vals[z]
            arr.append([i, j])
            vals[q] = arr
        else :
            vals[q] = [[i, j]]

# %%
vals
# Out:
# {7.2: [[0, 0]], 4.2: [[0, 1]], 9.0: [[1, 0]], 6.0: [[1, 1]]}

# %%
ans = []

# %%
for z in vals :
    max_val = -1
    for i in range(len(vals[z])) :
        q = vals[z][i]
        val = min(a[q[0]][1], b[q[1]][1])
        if(max_val == -1 or max_val <  val)  :
            max_val = val
    ans.append([z, max_val])

# %%
ans
# Out:
# [[7.2, 3.5], [4.2, 0.5], [9.0, 4.5], [6.0, 0.5]]
